# %%
import pandas as pd
import numpy as np
sal=pd.read_csv('salary.csv')
# Out:
# C:\Users\senta\AppData\Local\Temp\ipykernel_6624\157767395.py:3: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   sal=pd.read_csv('salary.csv')

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
#1.Display Top 10 Rows of The Dataset
sal.head(1)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN

# %%
#2. Check Last 10 Rows of The Dataset
sal.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647               NaN                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651               NaN                  Not provided  Not Provided
# 148651  148652               NaN                  Not provided  Not Provided
# 148652  148653               NaN                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
#3. Find Shape of Our Dataset (Number of Rows And Number of Columns)
print("Total number of rows in salary table is "+str(sal.shape[0]))
print("Total number of columns in salary table is "+str(sal.shape[1]))
# Out:
# Total number of rows in salary table is 148654
# Total number of columns in salary table is 13

# %%
#4. Getting Information About Our Dataset Like Total Number Rows,
#Total Number of Columns, Datatypes of Each Column And Memory Requirement
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   EmployeeName      148648 non-null  object
#  1   JobTitle          148654 non-null  object
#  2   BasePay           148049 non-null  object
#  3   OvertimePay       148654 non-null  object
#  4   OtherPay          148654 non-null  object
#  5   Benefits          112495 non-null  object
#  6   TotalPay          148654 non-null  float64
#  7   TotalPayBenefits  148654 non-null  float64
#  8   Year              148654 non-null  int64
#  9   Agency            148654 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.3+ MB

# %%
#5.Check Null Values In The Dataset
sal.isna().sum()
# Out:
# Id                       0
# EmployeeName             6
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
#6. Drop ID, Notes, Agency and Status Columns
sal.drop(['Id','Notes','Status'],axis=1,inplace=True)

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   EmployeeName      148654 non-null  object
#  1   JobTitle          148654 non-null  object
#  2   BasePay           148049 non-null  object
#  3   OvertimePay       148654 non-null  object
#  4   OtherPay          148654 non-null  object
#  5   Benefits          112495 non-null  object
#  6   TotalPay          148654 non-null  float64
#  7   TotalPayBenefits  148654 non-null  float64
#  8   Year              148654 non-null  int64
#  9   Agency            148654 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.3+ MB

# %%
#7. Get Overall Statistics About The Dataframe
sal.describe()
# Out:
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# 50%     71426.610000      92404.090000    2013.000000
# 75%    105839.135000     132876.450000    2014.000000
# max    567595.430000     567595.430000    2014.000000

# %%
#8. Find Occurrence of The Employee Names  (Top 5)
sal.groupby('EmployeeName').size().nlargest(5)
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# John Chan        9
# dtype: int64

# %%
# 9. Find The Number of Unique Job Titles
sal['JobTitle'].nunique()
# Out:
# 2159

# %%
#10. Total Number of Job Titles Contain Captain
sal[sal['JobTitle'].str.contains('Captain',case=False)].count()
# Out:
# EmployeeName        552
# JobTitle            552
# BasePay             551
# OvertimePay         552
# OtherPay            552
# Benefits            411
# TotalPay            552
# TotalPayBenefits    552
# Year                552
# Agency              552
# dtype: int64

# %%
#11. Display All the Employee Names From Fire Department
new=sal[sal['JobTitle'].str.contains('Fire',case=False)][['EmployeeName','JobTitle']]
new
# Out:
#               EmployeeName                                          JobTitle
# 4          PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 6                ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 8           MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9       JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10           ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...                    ...                                               ...
# 145956    Kenneth C Farris                                       Firefighter
# 147556       Edward A Dunn                                       Firefighter
# 148021      Kari A Johnson                                       Firefighter
# 148209        Sheryl K Lee                                       Firefighter
# 148554     Lawrence F Gatt                             Fire Alarm Dispatcher
#
# [5879 rows x 2 columns]

# %%
#12. Find Minimum, Maximum and Average BasePay
numeric_basepay = pd.to_numeric(sal['BasePay'], errors='coerce')
non_numeric_values = sal['BasePay'][numeric_basepay.isna()].unique()
print("Non-numeric values in BasePay:", non_numeric_values)
numeric_basepay.describe()
# Out:
# Non-numeric values in BasePay: [nan 'Not Provided']
# count    148045.000000
# mean      66325.448840
# std       42764.635495
# min        -166.010000
# 25%       33588.200000
# 50%       65007.450000
# 75%       94691.050000
# max      319275.010000
# Name: BasePay, dtype: float64

# %%
sal[sal['EmployeeName']=="Not provided"]
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
import numpy as np
sal['EmployeeName']=sal['EmployeeName'].replace("Not provided",np.nan)

# %%
sal['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
#14. Drop The Rows Having 5 Missing Values
sal[(sal.isnull().sum(axis=1)==2)]
# Out:
#       EmployeeName                                 JobTitle   BasePay  \
# 13797          NaN  PUBLIC SAFETY COMMUNICATIONS DISPATCHER  57963.39
#
#       OvertimePay OtherPay Benefits  TotalPay  TotalPayBenefits  Year  \
# 13797    19683.91  4373.86      NaN  82021.16          82021.16  2011
#
#               Agency
# 13797  San Francisco

# %%
#15. Find Job Title of ALBERT PARDINI
sal[sal['EmployeeName']=="ALBERT PARDINI"]['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
#16. How Much ALBERT PARDINI Make (Include Benefits) ?
sal[sal['EmployeeName']=="ALBERT PARDINI"]['TotalPayBenefits']
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %%
#17. Display Name of The Person Having The Highest BasePay
numeric_basepay.mean()
# Out:
# np.float64(66325.4488404877)

# %%
#18. Find Average BasePay of All Employee Per Year
sal.groupby('Year').mean(['numeric_basepay'])
# Out:
#           TotalPay  TotalPayBenefits
# Year
# 2011  71744.103871      71744.103871
# 2012  74113.262265     100553.229232
# 2013  77611.443142     101440.519714
# 2014  75463.918140     100250.918884

# %%
sal
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650                NaN                                    Not provided
# 148651                NaN                                    Not provided
# 148652                NaN                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...
